# %%
import pandas as pd
dp_data=pd.read_csv('C:/Users/kimkwanghee/Downloads/merge_data.csv')
dp_data_head=dp_data.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb9 in position 0: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-f3311724ae8d> in <module>
#       1 import pandas as pd
# ----> 2 dp_data=pd.read_csv('C:/Users/kimkwanghee/Downloads/merge_data.csv')
#       3 dp_data_head=dp_data.head()
#
# ...

# %%
dp_data
# Out:
#          custid         date_time store        product  brand   corner  \
# 0             0  2000-06-25 12:12   무역점  2116050008000  에스티로더  수입종합화장품
# 1             0  2000-06-25 12:42   무역점  4125440008000    시슬리  수입종합화장품
# 2             0  2000-08-26 18:10    본점  2116052008000   크리니크  수입종합화장품
# 3             0  2000-08-26 18:30    본점  4106430119900     듀퐁     수입의류
# 4             0  2000-09-03 18:02   무역점  2139141008000     랑콤  수입종합화장품
# ...         ...               ...   ...            ...    ...      ...
# 1036648   29998  2001-01-21 13:20   무역점  4241080013074    바닐라     영캐주얼
# 1036649   29998  2001-04-07 16:33   무역점  2139141008000     랑콤  수입종합화장품
# 1036650   29999  2001-03-21 18:03   천호점  4109290004000  루이까또즈      핸드백
# 1036651   29999  2001-03-29 18:23   천호점  4139350206500  소피에르핀      넥타이
# 1036652   29999  2001-04-21 13:13   천호점  4104840008000     샤넬  수입종합화장품
#
#               pc   part  imported  amount  discount  installment  gender  \
# ...

# %%
dp_data['part'].unique()
# Out:
# array(['명품잡화', '잡화파트', '남성의류', '골프/유니캐쥬얼', '로얄부띠끄', '케주얼,구두,아동', '여성캐주얼',
#        '여성의류파트', '가정용품', '가정용품파트', '남성정장스포츠', '아동', '잡화', '영어덜트캐쥬얼',
#        '영라이브', '공산품', '스포츠캐쥬얼', '여성정장', '아동문화', '공산품파트', '생식품파트', '영플라자',
#        '생식품', '패션잡화', '아동,스포츠', '로얄부틱', '여성캐쥬얼', '스포츠캐주얼', '영캐릭터',
#        '상품개발영업1과', '인터넷백화점'], dtype=object)

# %%
dp_data['brand'].unique()
# Out:
# array(['에스티로더', '시슬리', '크리니크', ..., '마트마켓팅', '오더메이드', '모둠삼방'],
#       dtype=object)

# %%
dp_data['pc'].unique()
# Out:
# array(['화장품', '명품토탈', '캐릭터정장', '트래디셔널', '로얄부띠끄', '아동복', '내의란제리', '영트렌디',
#        '캐릭터캐쥬얼', '여성캐주얼', '가전', '섬유잡화', '장신구', '트랜디 케쥬얼', '식기', '골프',
#        '수예', '유아/완구', '패션슈즈', '영트랜디', '조리식품', '진캐주얼', '스포츠', '아동',
#        '트래디셔널캐쥬얼', '가전/문화', '셔츠', '란제리', '영캐릭터캐쥬얼', '엘레강스캐쥬얼', '트레디셔널',
#        '정장', '일반식품', '축산물', '미확인pc', '진케주얼', '농산물', '문화용품', '생활용품', '문화',
#        '니트,단품,모피', '소품', '수산물', '미씨캐주얼', '타운란제리', '피혁A', '여성구두',
#        '디자이너부띠크', '핸드백', '진캐쥬얼', '명품시즌', '남여구두', '쇼핑보증', '수입명품', '로얄부틱',
#        '디자이너부틱', '미씨캐릭터', '캐쥬얼', '캐주얼', '영캐주얼', '섬유', '어덜트캐주얼', '침구수예',
#        '디자이너부띠끄', '악세사리', '캐릭터캐주얼', '피혁B', '니트/단품', '침구/수예', '가구', '남성잡화',
#        '패션시즌', '수입의류', '침구,수예', '(주)현스포츠아쌤', '용기보증', '아르모니아', '사이버쇼핑'],
#       dtype=object)

# %%
dp_data['corner'].unique()
# Out:
# array(['수입종합화장품', '수입의류', '캐릭터캐주얼', '트래디셔널', '로얄수입행사', '아동특선', '유아복',
#        '수입부띠끄', '란제리', '영트랜드', '캐릭터', '미시케쥬얼', '색조화장품', '가전특정', '스카프',
#        '헤어ACC', '영캐주얼', '주방용품', '골프웨어', '브랜드침구', '캐릭터슈즈', '행사', '즉석조리',
#        '진캐쥬얼', '스포츠슈즈', '아동복', '트래디셔널캐쥬얼', '영캐쥬얼', '취사소형', '넥타이', '미확인코너',
#        '셔츠', '욕실용품', '스포츠단품', '캐릭터캐쥬얼', '골프(LC)', '니트웨어', '내셔날', '유아',
#        '아동', '국내부띠끄', '수영복', '냉장식품', '수입', '정육', '용기보증', '진케주얼', '스포츠웨어',
#        '야채', '하이캐쥬얼', '팬시', '음료', '가정잡화', '문화', '타운단품', '임대을', '양말', '내의',
#        '차류', '진캐주얼', '모자', '임대을가전', '취미소품', '생선', '미씨캐릭터', '통병조림', '싸롱화',
#        '조미료', '건식품', '여성구두', '모피니트', '골프(국내)', '신생아', '임대화장품', '완구(문화)',
#        '스타킹', '소형전기', '머플러', '아웃도어', '타운웨어', '캐쥬얼구두', '잡화', '화장잡화', '테이프',
#        '수입ACC', '임대구두', '완구', '드레스구두', '패션시계', '부띠끄', '일반조리', '슈즈',
#        '로얄부틱2F', '수예침장', '곡물', '과자류', '의류기타', '엘레강스부틱', '일용잡화', '디자이너캐릭터',
#        '어덜트', '스포츠캐주얼', '패스트푸드', '단품/행사1', '영커리어캐주얼', '단품', '트레디셔널캐주얼',
# ...

# %%
dp_data['실매출액']=dp_data['amount']-dp_data['discount']
store_brand=dp_data.groupby(['store','brand']).sum()
store_brand=store_brand[['amount','discount','실매출액']]
store_brand
# Out:
#                  amount  discount      실매출액
# store brand
# 무역점   012베네통   37453670   1299720  36153950
#       1492마일즈  58375700   3085550  55290150
#       96NY     67875150   3124100  64751050
#       A-AND      855000         0    855000
#       AEG      14589800     26700  14563100
# ...                 ...       ...       ...
# 천호점   휠라슈즈     14614200    902650  13711550
#       휠라의류     24383800   1446050  22937750
#       휠라인티모      386500      2510    383990
#       휠라키즈     18859600   1052470  17807130
#       흙침대      13600000    109500  13490500
#
# [3971 rows x 3 columns]

# %%
store1=store_brand.loc['무역점']
store2=store_brand.loc['본점']
store3=store_brand.loc['신촌점']
store4=store_brand.loc['천호점']


store1_10=store1.sort_values(['실매출액'],ascending=False).head(10)
store2_10=store2.sort_values(['실매출액'],ascending=False).head(10)
store3_10=store3.sort_values(['실매출액'],ascending=False).head(10)
store4_10=store4.sort_values(['실매출액'],ascending=False).head(10)

store1_10['지점']='무역점'
store2_10['지점']='본점'
store3_10['지점']='신촌점'
store4_10['지점']='천호점'

store1_10
# Out:
#                amount  discount        실매출액   지점
# brand
# 식품         2467141334    109200  2467032134  무역점
# 시슬리         415193720  23210970   391982750  무역점
# 폴로          378825100  20518590   358306510  무역점
# 에스티로더       340360000  19348850   321011150  무역점
# 에뜨로         288651900  12521070   276130830  무역점
# 랑콤          276262500  15930730   260331770  무역점
# 버버리         266383000  14031050   252351950  무역점
# 페라가모현대무역점   261014900  12285040   248729860  무역점
# 타임          232546000  13863750   218682250  무역점
# 지오다노        214595000  11941820   202653180  무역점

# %%
dp_data[dp_data['brand']=='']['corner']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-05962b2ea075> in <module>
# ----> 1 dp_data['brand']==store1_10.index.tolist()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl  
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

plt.figure(figsize=(12,8))
plt.bar(store1_10.index.tolist(), store1_5['실매출액'].tolist(),color='green')
plt.title("점포별 브랜드별 실매출액", fontsize=15)
plt.xlabel('점포별 브랜드', fontsize=13)
plt.ylabel("실매출액", fontsize=13)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b1228bd3e222> in <module>
#       5
#       6 plt.figure(figsize=(12,8))
# ----> 7 plt.bar(store1_10.index.tolist(), store1_5['실매출액'].tolist(),color='green')
#       8 plt.title("점포별 브랜드별 실매출액", fontsize=15)
#       9 plt.xlabel('점포별 브랜드', fontsize=13)
#
# NameError: name 'store1_5' is not defined

# %%
store1_5.index.tolist()
# Out:
# ['식품', '시슬리', '폴로', '에스티로더', '에뜨로', '랑콤', '버버리', '페라가모현대무역점', '타임', '지오다노']

# %%
store1_10['실매출액'].tolist()
# Out:
# [2467032134,
#  391982750,
#  358306510,
#  321011150,
#  276130830,
#  260331770,
#  252351950,
#  248729860,
#  218682250,
#  202653180]

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl  
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

plt.figure(figsize=(25,15))

plt.subplot(221)
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.6)
plt.bar(store1_10.index.tolist(), store1_10['실매출액'].tolist(),color='yellowgreen')
plt.title("무역점의 상위 10개 브랜드 매출액", fontsize=20)
plt.xlabel('[무역점 상위 10개 브랜드]', fontsize=18)
plt.yticks(fontsize=15)
plt.xticks(rotation=45,fontsize=18)
plt.ylim(0,4000000000)
plt.ylabel("매출액(단위:10억)", fontsize=16)

plt.subplot(222)
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.6)
plt.bar(store2_10.index.tolist(), store2_10['실매출액'].tolist(),color='deepskyblue')
plt.title("본점의 상위 10개 브랜드 매출액", fontsize=20)
plt.xlabel('[본점 상위 10개 브랜드]', fontsize=18)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=15)
plt.ylim(0,4000000000)
plt.ylabel("매출액(단위:10억)", fontsize=16)

plt.subplot(223)
plt.bar(store3_10.index.tolist(), store3_10['실매출액'].tolist(),color='darkcyan')
plt.title("신촌점의 상위 10개 브랜드 매출액", fontsize=20)
plt.xlabel('[신촌점 상위 10개 브랜드]', fontsize=18)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=15)
plt.ylim(0,4000000000)
plt.ylabel("매출액(단위:10억)", fontsize=16)

plt.subplot(224)
plt.bar(store4_10.index.tolist(), store4_10['실매출액'].tolist(),color='saddlebrown')
plt.title("천호점의 상위 10개 브랜드 매출액", fontsize=20)
plt.xlabel('[천호점 상위 10개 브랜드]', fontsize=18)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=15)
plt.ylim(0,4000000000)
plt.ylabel("매출액(단위:10억)", fontsize=16)
plt.show()

# %%
store1=store_brand.loc['무역점']
store2=store_brand.loc['본점']
store3=store_brand.loc['신촌점']
store4=store_brand.loc['천호점']


store1_10_bad=store1.sort_values(['실매출액'],ascending=False).tail(10)
store2_10_bad=store2.sort_values(['실매출액'],ascending=False).tail(10)
store3_10_bad=store3.sort_values(['실매출액'],ascending=False).tail(10)
store4_10_bad=store4.sort_values(['실매출액'],ascending=False).tail(10)

store1_10_bad['지점']='무역점'
store2_10_bad['지점']='본점'
store3_10_bad['지점']='신촌점'
store4_10_bad['지점']='천호점'


store3_10_bad
# Out:
#            amount  discount    실매출액   지점
# brand
# 아산유통        12000         0   12000  신촌점
# 레카타클럽       10000         0   10000  신촌점
# 오즈랜드         7000         0    7000  신촌점
# 삼성그리팅카드      1200         0    1200  신촌점
# K2              0         0       0  신촌점
# 벨리스모D&G수입 -100000         0 -100000  신촌점
# 스톰        -118300         0 -118300  신촌점
# 니트롬       -122000         0 -122000  신촌점
# 모렐리(코리무역) -155000         0 -155000  신촌점
# 팬원(마리아니)  -425000         0 -425000  신촌점

# %%
dp_data[dp_data['brand']=='시슬리']['part']
# Out:
# 1               명품잡화
# 19         케주얼,구두,아동
# 20         케주얼,구두,아동
# 21         케주얼,구두,아동
# 78              명품잡화
#              ...
# 1036312         명품잡화
# 1036333         명품잡화
# 1036400         명품잡화
# 1036478         명품잡화
# 1036597        여성캐주얼
# Name: part, Length: 8141, dtype: object

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl  
plt.rcParams['axes.unicode_minus'] = False 
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

plt.figure(figsize=(27,15))
plt.subplot(221)
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.6)
plt.bar(store1_10_bad.index.tolist(), store1_10_bad['실매출액'].tolist(),color='yellowgreen')
plt.title("무역점의 하위 10개 브랜드 매출액", fontsize=20)
plt.xlabel('[무역점 하위 10개 브랜드]', fontsize=18)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=15)
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.ylim(-1500000,50000)
plt.ylabel("매출액(단위:100만)", fontsize=16)

plt.subplot(222)
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.6)
plt.bar(store2_10_bad.index.tolist(), store2_10_bad['실매출액'].tolist(),color='deepskyblue')
plt.title("본점의 하위 10개 브랜드 매출액", fontsize=20)
plt.xlabel('[본점 하위 10개 브랜드]', fontsize=18)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=15)
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.ylim(-1500000,50000)
plt.ylabel("매출액(단위:100만)", fontsize=16)

plt.subplot(223)
plt.bar(store3_10_bad.index.tolist(), store3_10_bad['실매출액'].tolist(),color='darkcyan')
plt.title("신촌점의 하위 10개 브랜드 매출액", fontsize=20)
plt.xlabel('[신촌점 하위 10개 브랜드]', fontsize=18)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=15)
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.ylim(-1500000,50000)
plt.ylabel("매출액(단위:100만)", fontsize=16)

plt.subplot(224)
plt.bar(store4_10_bad.index.tolist(), store4_10_bad['실매출액'].tolist(),color='saddlebrown')
plt.title("천호점의 하위 10개 브랜드 매출액", fontsize=20)
plt.xlabel('[천호점 하위 10개 브랜드]', fontsize=18)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=15)
plt.ylabel("매출액(단위:100만)", fontsize=16)
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
plt.ylim(-1500000,50000)
plt.show()

# %%
plt.figure(figsize=(27,15))

categories=store1_10.index.tolist()
plt.subplot(221)
plt.pie(store1_10['실매출액'].tolist(),labels=categories,autopct='%0.1f%%',)
plt.axis('equal')
plt.rcParams['font.size'] = 16
plt.xlabel('[무역점 상위 10개 브랜드]')
plt.legend(store1_10.index.tolist(),fontsize=15)

categories=store2_10.index.tolist()
plt.subplot(222)
plt.pie(store2_10['실매출액'].tolist(),labels=categories,autopct='%0.1f%%',)
plt.axis('equal')
plt.rcParams['font.size'] = 18
plt.xlabel('[본점 상위 10개 브랜드]', fontsize=15)
plt.legend(store2_10.index.tolist())

categories=store3_10.index.tolist()
plt.subplot(223)
plt.pie(store3_10['실매출액'].tolist(),labels=categories,autopct='%0.1f%%',)
plt.axis('equal')
plt.rcParams['font.size'] = 18
plt.xlabel('[신촌점 상위 10개 브랜드]', fontsize=15)
plt.legend(store3_10.index.tolist())

categories=store4_10.index.tolist()
plt.subplot(224)
plt.pie(store4_10['실매출액'].tolist(),labels=categories,autopct='%0.1f%%',)
plt.axis('equal')
plt.rcParams['font.size'] = 18
plt.xlabel('[천호점 상위 10개 브랜드]', fontsize=15)
plt.legend(store4_10.index.tolist())
plt.show()

# %%
event_brand=df.groupby(['brand']).sum()

# %% [markdown]
# ### 이벤트기간 무역점

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl  
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

plt.figure(figsize=(25,20))

plt.subplot(221)
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.3)
plt.bar(seol_trade_brand.index.tolist(),seol_trade_brand['실매출액'].tolist() ,color='olive')
plt.title("설 기준 무역점의 매출액 상위 10개 브랜드", fontsize=20)
plt.xticks(rotation=45,fontsize=18)
plt.xlabel('[브랜드]', fontsize=20)
plt.yticks(fontsize=18)
plt.ylabel("매출액(단위:1000만)", fontsize=18)

plt.subplot(222)
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.3)
plt.bar(valen_trade_brand.index.tolist(),valen_trade_brand['실매출액'].tolist(),color='orange')
plt.title("발렌타인 기준 무역점의 매출액 상위 10개 브랜드", fontsize=20)
plt.xticks(rotation=45,fontsize=18)
plt.xlabel('[브랜드]', fontsize=20)
plt.yticks(fontsize=18)
plt.ylabel("매출액(단위:1000만)", fontsize=18)

plt.subplot(223)
plt.bar(chuseok_trade_brand.index.tolist(),chuseok_trade_brand['실매출액'].tolist(),color='limegreen')
plt.title('추석 기준 무역점의 상위 매출액 10개 브랜드', fontsize=20)
plt.xlabel('[브랜드]', fontsize=20)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel("매출액(단위:1000만)", fontsize=18)

plt.subplot(224)
plt.bar(chris_trade_brand.index.tolist(),chris_trade_brand['실매출액'].tolist(),color='deepskyblue')
plt.title("크리스마스 기준 무역점의 매출액 상위 10개 브랜드", fontsize=20)
plt.xlabel('[브랜드]', fontsize=20)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel("매출액(단위:1000만)", fontsize=18)
plt.show()

# %% [markdown]
# ### 이벤트기간 본점

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl  
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

plt.figure(figsize=(25,20))

plt.subplot(221)
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
plt.bar(main_seol_brand.index.tolist(),main_seol_brand['실매출액'].tolist() ,color='olive')
plt.title("설 기준 본점의 매출액 상위 10개 브랜드", fontsize=20)
plt.xlabel('[브랜드]', fontsize=20)
plt.yticks(fontsize=18)
plt.xticks(rotation=45,fontsize=18)
plt.ylabel("매출액(단위:1억)", fontsize=18)

plt.subplot(222)
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.5)
plt.bar(main_valen_brand.index.tolist(),main_valen_brand['실매출액'].tolist(),color='orange')
plt.title("발렌타인 기준 본점의 매출액 상위 10개 브랜드", fontsize=20)
plt.xlabel('[브랜드]', fontsize=20)
plt.yticks(fontsize=18)
plt.xticks(rotation=45,fontsize=18)
plt.ylabel("매출액(단위:1000만)", fontsize=18)

plt.subplot(223)
plt.bar(main_chuseok_brand.index.tolist(),main_chuseok_brand['실매출액'].tolist(),color='limegreen')
plt.title('추석 기준 본점의 상위 매출액 10개 브랜드', fontsize=20)
plt.xlabel('[브랜드]', fontsize=20)
plt.yticks(fontsize=18)
plt.xticks(rotation=45,fontsize=18)
plt.ylabel("매출액(단위:1억)", fontsize=18)

plt.subplot(224)
plt.bar(main_chris_brand.index.tolist(),main_chris_brand['실매출액'].tolist(),color='deepskyblue')
plt.title("크리스마스 기준 본점의 매출액 상위 10개 브랜드", fontsize=20)
plt.xlabel('[브랜드]', fontsize=20)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel("매출액(단위:1000만)", fontsize=18)
plt.show()

# %% [markdown]
# ### 이번트 기간 신촌점

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl  
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

plt.figure(figsize=(25,20))

plt.subplot(221)
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.4)
plt.bar(sc_seol_brand.index.tolist(),sc_seol_brand['실매출액'].tolist(),color='olive')
plt.title("설 기준 신촌점의 매출액 상위 10개 브랜드", fontsize=20)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('[브랜드]', fontsize=20)
plt.ylabel("매출액(단위:1000만)", fontsize=18)

plt.subplot(222)
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.4)
plt.bar(sc_valen_brand.index.tolist(),sc_valen_brand['실매출액'].tolist(),color='orange')
plt.title("발렌타인 기준 신촌점의 매출액 상위 10개 브랜드", fontsize=20)
plt.yticks(fontsize=18)
plt.xlabel('[브랜드]', fontsize=20)
plt.xticks(rotation=45,fontsize=18)
plt.ylabel("매출액(단위:1000만)", fontsize=16)

plt.subplot(223)
plt.bar(sc_chuseok_brand.index.tolist(),sc_chuseok_brand['실매출액'].tolist(),color='limegreen')
plt.title('추석 기준 신촌점의 상위 매출액 10개 브랜드', fontsize=20)
plt.xlabel('[브랜드]', fontsize=20)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('[브랜드]', fontsize=20)
plt.ylabel("매출액(단위:1000만)", fontsize=16)

plt.subplot(224)
plt.bar(sc_chris_brand.index.tolist(),sc_chris_brand['실매출액'].tolist(),color='deepskyblue')
plt.title("크리스마스 기준 신촌점의 매출액 상위 10개 브랜드", fontsize=20)
plt.xlabel('[브랜드]', fontsize=20)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('[브랜드]', fontsize=20)
plt.ylabel("매출액(단위:1000만)", fontsize=16)
plt.show()

# %% [markdown]
# ### 이벤트 기간 천호점

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl  
font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
mpl.rc('font', family=font_name)

plt.figure(figsize=(25,20))

plt.subplot(221)
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.4)
plt.bar(cheonho_seol_brand.index.tolist(),cheonho_seol_brand['실매출액'].tolist(),color='olive')
plt.title("설 기준 천호점의 매출액 상위 10개 브랜드", fontsize=20)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('[브랜드]', fontsize=20)
plt.ylabel("매출액(단위:1000만)", fontsize=18)

plt.subplot(222)
plt.subplots_adjust(left=0.125, bottom=0.1,  right=0.9, top=0.9, wspace=0.2, hspace=0.4)
plt.bar(cheonho_valen_brand.index.tolist(),cheonho_valen_brand['실매출액'].tolist(),color='orange')
plt.title("발렌타인 기준 천호점의 매출액 상위 10개 브랜드", fontsize=20)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('[브랜드]', fontsize=20)
plt.ylabel("매출액(단위:1000만)", fontsize=18)

plt.subplot(223)
plt.bar(cheonho_chuseok_brand.index.tolist(),cheonho_chuseok_brand['실매출액'].tolist(),color='limegreen')
plt.title('추석 기준 천호점의 상위 매출액 10개 브랜드', fontsize=20)
plt.xlabel('[브랜드]', fontsize=20)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel("매출액(단위:1000만)", fontsize=18)

plt.subplot(224)
plt.bar(cheonho_chris_brand.index.tolist(),cheonho_chris_brand['실매출액'].tolist(),color='deepskyblue')
plt.title("크리스마스 기준 천호점의 매출액 상위 10개 브랜드", fontsize=20)
plt.xlabel('[브랜드]', fontsize=20)
plt.xticks(rotation=45,fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel("매출액(단위:1000만)", fontsize=18)
plt.show()

# %%
chuseok_trade_brand=pd.read_csv('trade_chuseok.csv')
chuseok_trade_brand=chuseok_trade_brand.groupby(['brand']).sum()
chuseok_trade_brand['실매출액']=chuseok_trade_brand['amount']-chuseok_trade_brand['discount']
chuseok_trade_brand=chuseok_trade_brand.sort_values(['실매출액'],ascending=False).head(10)
chuseok_trade_brand
# Out:
#             custid           product  imported    amount  discount  \
# brand
# 식품         9773337  1792800000000000         0  44257047         0
# 폴로          683517   303166080955200         0   6316100    423200
# 레노마골프       146344    39643470225000         0   3144000    157200
# 애티튜드         21732    12680820030000         0   2885000    144250
# 지오다노        937050   273148441612822         0   2901800    183510
# 시슬리         222165    62403455135000        10   2609000    143650
# 랑콤          577553    72730794272000         0   2421000    152800
# 페라가모현대무역점   193007    55251360090630         9   2225000    111250
# 오스틴리드        41089    18924243045300         0   2109750         0
# 지엔알모다1        9789     4132031010000         0   2200000    110000
#
#            installment  gender  time_label      실매출액
# brand
# 식품                 805     258        1737  44257047
# 폴로                 122      20         137   5892900
# 레노마골프               28       3          18   2986800
# ...

# %%
chris_trade_brand=pd.read_csv('trade_chris.csv')
chris_trade_brand=chris_trade_brand.groupby(['brand']).sum()
chris_trade_brand['실매출액']=chris_trade_brand['amount']-chris_trade_brand['discount']
chris_trade_brand=chris_trade_brand.sort_values(['실매출액'],ascending=False).head(10)
chris_trade_brand
# Out:
#              custid           product  imported    amount  discount  \
# brand
# 식품         10247208  1919700000000000         0  28264441         0
# 에뜨로          378327    98855045040200        24   8500000     97300
# 버버리          307530    98419973040440        24   8465500    111000
# 크리스찬디올무역점    112275    49130320080090         0   6101000         0
# 까르띠에무역센타점    225614    85739500204600        14   4660000         0
# 진도모피          54371    12625141534800         0   4699000    234950
# 에스티로더        714630    97338300368000        46   4447000    269300
# 시슬리          448045   133788387307510        15   4221000    133340
# 솔리드옴므         81230    25862400119400         0   3538000    176900
# 구찌현대무역점      187804    61398300100700        10   3520000    176000
#
#            installment  gender  time_label      실매출액
# brand
# 식품                 751     264        2004  28264441
# 에뜨로                 57      12          65   8402700
# ...

# %%
seol_trade_brand=pd.read_csv('trade_seol.csv')
seol_trade_brand=seol_trade_brand.groupby(['brand']).sum()
seol_trade_brand['실매출액']=seol_trade_brand['amount']-seol_trade_brand['discount']
seol_trade_brand=seol_trade_brand.sort_values(['실매출액'],ascending=False).head(10)
seol_trade_brand
# Out:
#         custid          product  imported    amount  discount  installment  \
# brand
# 식품     3418419  572400000000000         0  18148048         0          246
# 옥동       67332   12619890330053         0   7552800    405500            9
# 이원재      48443    8413920020030         0   3800000    580000            6
# 삼성       19589    4502160936000         0   1838000         0            3
# 김혜경      12114    4238710010000         0   2000000    200000            6
# 진도모피       458    4208380511600         0   1665000         0            3
# 폴로      235660   65916400271150         0   1447900     58500           25
# 랑콤      250648   34226256128000         0   1298000     84050           26
# 엘르       21416    8420912020020         0   1170000     23300            6
# 데무       25509    4203760010063         0   1115500         0            3
#
#        gender  time_label      실매출액
# brand
# 식품         80         609  18148048
# 옥동          0           6   7147300
# ...

# %%
valen_trade_brand=pd.read_csv('trade_valen.csv')
valen_trade_brand=valen_trade_brand.groupby(['brand']).sum()
valen_trade_brand['실매출액']=valen_trade_brand['amount']-valen_trade_brand['discount']
valen_trade_brand=valen_trade_brand.sort_values(['실매출액'],ascending=False).head(10)
valen_trade_brand
# Out:
#          custid           product  imported    amount  discount  installment  \
# brand
# 식품     18376795  3339900000000000         0  36418927         0         1303
# 와코루     3290701   945144048365280       225  17733400    118800          521
# 폴로       842422   343818641146700         0   6739000    385850          119
# 에스티듀퐁    166719    41064302069060        10   6223500    401450           29
# 시슬리      788819   195983100436000        27   5853000    310900          124
# 우드모드      85955    18098403778213         0   5533260     45260           12
# 메조피아노    400877   110194025511825        25   5170950         0           67
# 삼성       140845    49523772282401         0   5131900     64260           37
# 아모레      930529   226012050440000         0   5279500    271430          104
# 루치아노최      7062    12608850033075         0   5146000    241050            9
#
#        gender  time_label      실매출액
# brand
# 식품        387        3488  36418927
# ...

# %%
main_seol_brand=pd.read_csv('main_seol (1).csv')
main_seol_brand=main_seol_brand.groupby(['brand']).sum()
main_seol_brand['실매출액']=main_seol_brand['amount']-main_seol_brand['discount']
main_seol_brand=main_seol_brand.sort_values(['실매출액'],ascending=False).head(10)
main_seol_brand
# Out:
#            custid           product  imported     amount  discount  \
# brand
# 식품       23329951  4195800000000000         0  121109516         0
# 진도모피        57544    12625140034801         0   10590000    529500
# 구찌         256542   110482020222254        18    8385000    325000
# 프라다현대본점    444483   147337200300570        24    7969000         0
# 근화모피        31134    16805240049356         0    8185000    409250
# 미쏘니1        99974    16432122040090         4    5528300    164800
# 시슬리        537121   148620211291200        35    5334000    314350
# 박윤수         28054     4206650110000         0    5000000    250000
# 샤넬        1084457   320177520624000        78    5010000    278250
# 미스지        106048    29459080082374         0    4488000         0
#
#          installment  gender  time_label       실매출액
# brand
# 식품              1748     745        4045  121109516
# 진도모피               7       2           8   10060500
# 구찌                50      10          55    8060000
# ...

# %%
main_valen_brand=pd.read_csv('main_valen.csv')
main_valen_brand=main_valen_brand.groupby(['brand']).sum()
main_valen_brand['실매출액']=main_valen_brand['amount']-main_valen_brand['discount']
main_valen_brand=main_valen_brand.sort_values(['실매출액'],ascending=False).head(10)
main_valen_brand
# Out:
#                custid           product  imported    amount  discount  \
# brand
# 식품           21516239  3809700000000000         0  48708916         0
# 와코루           4386866  1289596484589960       307  22207000    198050
# 루이비통           385047   153316000312500        25  11933000         0
# 이상봉             94994    21037000050060         0  10046800    490400
# 에르메스부틱현대백화점    162562    55244520090000         9   7534000         0
# 이유덕             17332     4234320010000         0   7890000    394500
# 에스티로더          810894   129079050488000        61   7546000    425200
# 시슬리            554032   161727128337653        31   7111900    364700
# 폴로            1110195   410538051293500         0   6409000    359450
# 티파니            166656    73491384118800        12   5640000         0
#
#              installment  gender  time_label      실매출액
# brand
# 식품                  1423     605        3908  48708916
# 와코루                  635     130         813  22008950
# ...

# %%
main_chuseok_brand=pd.read_csv('main_chuseok.csv')
main_chuseok_brand=main_chuseok_brand.groupby(['brand']).sum()
main_chuseok_brand['실매출액']=main_chuseok_brand['amount']-main_chuseok_brand['discount']
main_chuseok_brand=main_chuseok_brand.sort_values(['실매출액'],ascending=False).head(10)
main_chuseok_brand
# Out:
#             custid           product  imported     amount  discount  \
# brand
# 식품        18456154  3377700000000000         0  101989333         0
# 루이비통        263366   116520160237500        19    7436000         0
# 막스마라        242559    49308001320000        12    7002000    400000
# 질샌더          85268    16456288040000         4    6780000    339000
# 폴로          747145   309482530975100         0    6749200    381000
# 티파니          77747    30621410043500         5    6210000         0
# 페라가모현대본점    327970   122780600200000        20    5386000    269300
# 아이그너         82942    12322053030000         3    5384000    492700
# 샤넬          836803   262709760512000        64    5007000    308400
# 버버리         102964    32806657680000         8    4990000    314000
#
#           installment  gender  time_label       실매출액
# brand
# 식품               1445     618        3221  101989333
# 루이비통               55       2          51    7436000
# ...

# %%
main_chris_brand=pd.read_csv('main_chris.csv')
main_chris_brand=main_chris_brand.groupby(['brand']).sum()
main_chris_brand['실매출액']=main_chris_brand['amount']-main_chris_brand['discount']
main_chris_brand=main_chris_brand.sort_values(['실매출액'],ascending=False).head(10)
main_chris_brand
# Out:
#             custid           product  imported    amount  discount  \
# brand
# 식품        13330825  2327400000000000         0  39379541         0
# 레오나드수입의류     33440     8250760021678         2  18028600    530400
# 까르띠에본점      160787    67366640205900        11  11191000         0
# 버버리         564065   127125798510430        31  10004500    344250
# 진도모피         20532    12625140034800         0   9470000    473500
# 폴로          932628   378958201194000         0   8128100    428800
# 페라가모현대본점    374489   147336720240000        24   6457000    322850
# 에뜨로         212230    70022323570080        17   6149800    139700
# 듀퐁          159654    36957871979220         0   5840100         0
# 에스티로더       795240   116382750440000        55   6055000    377050
#
#           installment  gender  time_label      실매출액
# brand
# 식품                888     406        2283  39379541
# 레오나드수입의류           18       2           6  17498200
# 까르띠에본점             41       3          29  11191000
# ...

# %%
cheonho_seol_brand=pd.read_csv('cheonho_seol.csv')
cheonho_seol_brand=cheonho_seol_brand.groupby(['brand']).sum()
cheonho_seol_brand['실매출액']=cheonho_seol_brand['amount']-cheonho_seol_brand['discount']
cheonho_seol_brand=cheonho_seol_brand.sort_values(['실매출액'],ascending=False).head(10)
cheonho_seol_brand
# Out:
#            custid           product  imported    amount  discount  \
# brand
# 식품       12287477  2270700000000000         0  55737928         0
# 성진모피        41116    12647340034800         0   8156000    407800
# 아모레        622206   160263090312000         0   3821000    212450
# 랑콤         564235    79148217296000         0   3049000    168200
# 이원재         16518     4206960010053         0   2750000         0
# 시슬리        339209    96033201237770        12   2830600    110100
# 지오다노       810273   242309106105065         0   2784600    155290
# 다우닝         18532     4506890944071         0   2700000     81000
# 인스페이스코인    132931    31759566626690         0   2445200         0
# 제네시스        28247    12260700012000         0   2328000         0
#
#          installment  gender  time_label      실매출액
# brand
# 식품              1212     308        2243  55737928
# 성진모피              12       0           9   7748200
# 아모레               88       5         114   3608550
# ...

# %%
cheonho_valen_brand=pd.read_csv('cheonho_valen.csv')
cheonho_valen_brand=cheonho_valen_brand.groupby(['brand']).sum()
cheonho_valen_brand['실매출액']=cheonho_valen_brand['amount']-cheonho_valen_brand['discount']
cheonho_valen_brand=cheonho_valen_brand.sort_values(['실매출액'],ascending=False).head(10)
cheonho_valen_brand
# Out:
#          custid           product  imported    amount  discount  installment  \
# brand
# 식품     10990271  2014200000000000         0  22417701         0          891
# 근화모피      13376     8402620223200         0   9160000    363000            6
# 와코루     1438206   420064011397625         1   8009100     30550          222
# 시슬리      603923   152641280296000        37   8266000    451450          112
# 아모레      903849   213684120416000         0   5626500    336830          109
# 샤넬      1035877   270919440528000        66   4635400    245770          125
# 닥스숙녀     314228    80131172133066         0   3386000     98000           62
# 지오다노    1273927   356855222276000         0   3195600    166880          124
# 아이그너      26174    12322053030030         3   2704400     77400           12
# 랑콤       617810    83426499312000         0   2766000    151050           71
#
#        gender  time_label      실매출액
# brand
# 식품        240        2026  22417701
# ...

# %%
cheonho_chuseok_brand=pd.read_csv('cheonho_chuseok.csv')
cheonho_chuseok_brand=cheonho_chuseok_brand.groupby(['brand']).sum()
cheonho_chuseok_brand['실매출액']=cheonho_chuseok_brand['amount']-cheonho_chuseok_brand['discount']
cheonho_chuseok_brand=cheonho_chuseok_brand.sort_values(['실매출액'],ascending=False).head(10)
cheonho_chuseok_brand
# Out:
#              custid           product  imported    amount  discount  \
# brand
# 식품         10659527  1946700000000000         0  46818389         0
# 폴로           575949   172488000796000         0   5359000    307900
# 가이거           26029    12352290030000         3   3850000    314000
# 지오다노        1582102   418533910553288         0   3678400    198360
# 시슬리          216254    66528895143000        11   2581000    129050
# 폴로진          261103    80603510494000         0   2431000    135050
# 페라가모          70776    30698600050350         5   2345000    124000
# 크리스챤디올화장품    269827    78074040152000        19   2276000    122350
# 루치아노최        122405    33623600101518         0   2015000      5450
# 아모레          389378   106842060208000         0   2089000    134600
#
#            installment  gender  time_label      실매출액
# brand
# 식품                1106     248        1836  46818389
# 폴로                  91      24         109   5051100
# ...

# %%
cheonho_chris_brand=pd.read_csv('cheonho_chris.csv')
cheonho_chris_brand=cheonho_chris_brand.groupby(['brand']).sum()
cheonho_chris_brand['실매출액']=cheonho_chris_brand['amount']-cheonho_chris_brand['discount']
cheonho_chris_brand=cheonho_chris_brand.sort_values(['실매출액'],ascending=False).head(10)
cheonho_chris_brand
# Out:
#         custid           product  imported    amount  discount  installment  \
# brand
# 식품     6744952  1244700000000000         0  17411469         0          583
# 브니엘     153011    49042720048000         0   5900000         0           51
# 수입A/V    67263    18218243724281         0   5458000         0           19
# 근화모피     42613     8402620223200         0   5380000    179000            6
# 샤넬      716707   205242000400000        50   3320000    181000           80
# 아모레     472146   152044470296000         0   3060000    155600           75
# 성진모피     83416    12647340034800         0   2840000    142000           27
# 아이그너    153726    32858808080120         8   2383900    -29400           22
# 닥스      237353    51330010195655         0   2413000     18050           25
# 버버리      96111    28705824070140         7   2393500     43500           19
#
#        gender  time_label      실매출액
# brand
# 식품        179        1312  17411469
# 브니엘         0          23   5900000
# ...

# %%
sc_seol_brand=pd.read_csv('sc_seol.csv')
sc_seol_brand=sc_seol_brand.groupby(['brand']).sum()
sc_seol_brand['실매출액']=sc_seol_brand['amount']-sc_seol_brand['discount']
sc_seol_brand=sc_seol_brand.sort_values(['실매출액'],ascending=False).head(10)
sc_seol_brand
# Out:
#          custid           product  imported    amount  discount  installment  \
# brand
# 식품     16487750  3032100000000000         0  83524016         0         1708
# 랑콤       880749   130487601488000         0   5167000    254200          126
# 에스티로더    739444   103686450392000        49   5091000    310100          108
# 아이덴티     786758   231574811219070         0   3651200     21580          115
# 샤넬       914078   229871040448000        56   3741000    203550           91
# 크리니크     954427   131195224496000        62   3620000    200750          107
# 근화모피      18848     4201310011600         0   3300000    165000           10
# YK038     31798    12693270036152         0   3458000    325000            7
# 아모레      505612   147935160288000         0   3064000    163450           63
# 폴로       360252   112117200517430         0   2942500    154400           57
#
#        gender  time_label      실매출액
# brand
# 식품        387        3035  83524016
# ...

# %%
sc_valen_brand=pd.read_csv('sc_seol.csv')
sc_valen_brand=sc_valen_brand.groupby(['brand']).sum()
sc_valen_brand['실매출액']=sc_valen_brand['amount']-sc_valen_brand['discount']
sc_valen_brand=sc_valen_brand.sort_values(['실매출액'],ascending=False).head(10)
sc_valen_brand
# Out:
#          custid           product  imported    amount  discount  installment  \
# brand
# 식품     16487750  3032100000000000         0  83524016         0         1708
# 랑콤       880749   130487601488000         0   5167000    254200          126
# 에스티로더    739444   103686450392000        49   5091000    310100          108
# 아이덴티     786758   231574811219070         0   3651200     21580          115
# 샤넬       914078   229871040448000        56   3741000    203550           91
# 크리니크     954427   131195224496000        62   3620000    200750          107
# 근화모피      18848     4201310011600         0   3300000    165000           10
# YK038     31798    12693270036152         0   3458000    325000            7
# 아모레      505612   147935160288000         0   3064000    163450           63
# 폴로       360252   112117200517430         0   2942500    154400           57
#
#        gender  time_label      실매출액
# brand
# 식품        387        3035  83524016
# ...

# %%
sc_chuseok_brand=pd.read_csv('sc_chuseok.csv')
sc_chuseok_brand=sc_chuseok_brand.groupby(['brand']).sum()
sc_chuseok_brand['실매출액']=sc_chuseok_brand['amount']-sc_chuseok_brand['discount']
sc_chuseok_brand=sc_chuseok_brand.sort_values(['실매출액'],ascending=False).head(10)
sc_chuseok_brand
# Out:
#          custid           product  imported    amount  discount  installment  \
# brand
# 식품     14735180  2678400000000000         0  62384179         0         1506
# 폴로       600807   176800200815900         0   5103000    304150           88
# 샤넬       793575   188822640368000        46   3626000    204950           78
# 지오다노    1132432   348043982054548         0   3480800    188510          109
# 빈폴       338368   170592075537300         0   3455000    198950           52
# 랑콤       741825   119791896448000         0   3317000    190550           91
# 손정완       78319    21089250056148         0   2996000    125500           15
# 에스티로더    584005    78293850296000        37   3000000    166900           69
# 솔리드옴므     36897    12931200059700         0   2874000    269500            5
# 이신우옴므     77324    21603800099500         0   2702000    196300           11
#
#        gender  time_label      실매출액
# brand
# 식품        318        2535  62384179
# ...

# %%
sc_chris_brand=pd.read_csv('sc_chris.csv')
sc_chris_brand=sc_chris_brand.groupby(['brand']).sum()
sc_chris_brand['실매출액']=sc_chris_brand['amount']-sc_chris_brand['discount']
sc_chris_brand=sc_chris_brand.sort_values(['실매출액'],ascending=False).head(10)
sc_chris_brand
# Out:
#         custid           product  imported    amount  discount  installment  \
# brand
# 식품     8789254  1598400000000000         0  23394600         0          758
# 진도모피     73653    12625140036280         0   8330000    416500           15
# 샤넬      899651   213451680416000        52   3537000    206500           88
# 버버리     151722    53310816137680        13   3413000    176000           27
# 지오다노    845379   268742821589213         0   3084100     85770          103
# 에스티로더   725437   101570400384000        48   3129000    174950           95
# 오즈세컨    308715    80204892109570         0   2813000     36120           61
# 랑콤      763734   104817909392000         0   2815000    163650           76
# XinX     46828    33618288208000         0   2648000    170350           21
# 마인      123709    37828440090000         0   2530000    145500           27
#
#        gender  time_label      실매출액
# brand
# 식품        175        1642  23394600
# 진도모피        2          10   7913500
# ...

# %%
timeLabel=pd.read_csv('add_time_label.csv')
timeLabel['profit']=timeLabel['amount']-timeLabel['discount']
#월별 데이터 가져오기
monthly=timeLabel.loc[:,['date_time','store','profit']]
#무역점 7월 데이터 가져오기
trade = monthly.query("store == '무역점'")
trade_data = trade.sort_values('date_time').reset_index().drop(columns='index')
tradeJuly= (trade['date_time'] >= '2000-07-01') & (trade['date_time'] <= '2000-07-31')
july=trade.loc[tradeJuly]
# 무역점 7월 profit 합계
july.profit.sum()
# Out:
# 2370545026

# %%
july
# Out:
#                 date_time store   profit
# 24       2000-07-08 11:50   무역점   126000
# 78       2000-07-27 14:03   무역점    57000
# 79       2000-07-27 14:43   무역점   357200
# 80       2000-07-27 14:50   무역점    49000
# 81       2000-07-30 14:40   무역점   560000
# ...                   ...   ...      ...
# 1036541  2000-07-23 10:30   무역점   455000
# 1036542  2000-07-23 11:03   무역점    42750
# 1036543  2000-07-25 17:10   무역점  1506000
# 1036544  2000-07-27 14:40   무역점    64000
# 1036641  2000-07-29 14:00   무역점    45600
#
# [26806 rows x 3 columns]

# %%
trade_data
# Out:
#                date_time store  profit
# 0       2000-05-01 10:03   무역점   13300
# 1       2000-05-01 10:20   무역점    7000
# 2       2000-05-01 10:23   무역점   43700
# 3       2000-05-01 10:30   무역점   19000
# 4       2000-05-01 10:30   무역점  242250
# ...                  ...   ...     ...
# 284221  2001-04-29 19:31   무역점   56430
# 284222  2001-04-29 19:33   무역점  302100
# 284223  2001-04-29 19:33   무역점   98750
# 284224  2001-04-29 19:44   무역점   42180
# 284225  2001-04-29 19:54   무역점  136800
#
# [284226 rows x 3 columns]

# %%
timeLabel=pd.read_csv('add_time_label.csv')
timeLabel['profit']=timeLabel['amount']-timeLabel['discount']
#월별 데이터 가져오기
monthly=timeLabel.loc[:,['date_time','store','profit']]


trade = monthly.query("store == '무역점'")

trade_7= (trade['date_time'] >= '2000-07-01') & (trade['date_time'] <= '2000-07-31')
trade_8= (trade['date_time'] >= '2000-08-01') & (trade['date_time'] <= '2000-08-31')
trade_9= (trade['date_time'] >= '2000-09-01') & (trade['date_time'] <= '2000-09-31')
trade_10= (trade['date_time'] >= '2000-10-01') & (trade['date_time'] <= '2000-10-31')
trade_11= (trade['date_time'] >= '2000-11-01') & (trade['date_time'] <= '2000-11-31')
trade_12= (trade['date_time'] >= '2000-12-01') & (trade['date_time'] <= '2000-12-31')
trade_1= (trade['date_time'] >= '2001-01-01') & (trade['date_time'] <= '2001-01-31')
trade_2= (trade['date_time'] >= '2001-02-01') & (trade['date_time'] <= '2001-02-31')
trade_3= (trade['date_time'] >= '2001-03-01') & (trade['date_time'] <= '2001-03-31')
trade_4= (trade['date_time'] >= '2001-04-01') & (trade['date_time'] <= '2001-04-31')

trade_profit=[]
trade_profit.append(trade.loc[trade_7].profit.sum())
trade_profit.append(trade.loc[trade_8].profit.sum())
trade_profit.append(trade.loc[trade_9].profit.sum())
trade_profit.append(trade.loc[trade_10].profit.sum())
trade_profit.append(trade.loc[trade_11].profit.sum())
trade_profit.append(trade.loc[trade_12].profit.sum())
trade_profit.append(trade.loc[trade_1].profit.sum())
trade_profit.append(trade.loc[trade_2].profit.sum())
trade_profit.append(trade.loc[trade_3].profit.sum())
trade_profit.append(trade.loc[trade_4].profit.sum())

origin = monthly.query("store == '본점'")

origin_7= (origin['date_time'] >= '2000-07-01') & (origin['date_time'] <= '2000-07-31')
origin_8= (origin['date_time'] >= '2000-08-01') & (origin['date_time'] <= '2000-08-31')
origin_9= (origin['date_time'] >= '2000-09-01') & (origin['date_time'] <= '2000-09-31')
origin_10= (origin['date_time'] >= '2000-10-01') & (origin['date_time'] <= '2000-10-31')
origin_11= (origin['date_time'] >= '2000-11-01') & (origin['date_time'] <= '2000-11-31')
origin_12= (origin['date_time'] >= '2000-12-01') & (origin['date_time'] <= '2000-12-31')
origin_1= (origin['date_time'] >= '2001-01-01') & (origin['date_time'] <= '2001-01-31')
origin_2= (origin['date_time'] >= '2001-02-01') & (origin['date_time'] <= '2001-02-31')
origin_3= (origin['date_time'] >= '2001-03-01') & (origin['date_time'] <= '2001-03-31')
origin_4= (origin['date_time'] >= '2001-04-01') & (origin['date_time'] <= '2001-04-31')

origin_profit=[]
origin_profit.append(origin.loc[origin_7].profit.sum())
origin_profit.append(origin.loc[origin_8].profit.sum())
origin_profit.append(origin.loc[origin_9].profit.sum())
origin_profit.append(origin.loc[origin_10].profit.sum())
origin_profit.append(origin.loc[origin_11].profit.sum())
origin_profit.append(origin.loc[origin_12].profit.sum())
origin_profit.append(origin.loc[origin_1].profit.sum())
origin_profit.append(origin.loc[origin_2].profit.sum())
origin_profit.append(origin.loc[origin_3].profit.sum())
origin_profit.append(origin.loc[origin_4].profit.sum())


sc= monthly.query("store == '신촌점'")

sc_7= (sc['date_time'] >= '2000-07-01') & (sc['date_time'] <= '2000-07-31')
sc_8= (sc['date_time'] >= '2000-08-01') & (sc['date_time'] <= '2000-08-31')
sc_9= (sc['date_time'] >= '2000-09-01') & (sc['date_time'] <= '2000-09-31')
sc_10= (sc['date_time'] >= '2000-10-01') & (sc['date_time'] <= '2000-10-31')
sc_11= (sc['date_time'] >= '2000-11-01') & (sc['date_time'] <= '2000-11-31')
sc_12= (sc['date_time'] >= '2000-12-01') & (sc['date_time'] <= '2000-12-31')
sc_1= (sc['date_time'] >= '2001-01-01') & (sc['date_time'] <= '2001-01-31')
sc_2= (sc['date_time'] >= '2001-02-01') & (sc['date_time'] <= '2001-02-31')
sc_3= (sc['date_time'] >= '2001-03-01') & (sc['date_time'] <= '2001-03-31')
sc_4= (sc['date_time'] >= '2001-04-01') & (sc['date_time'] <= '2001-04-31')

sc_profit=[]
sc_profit.append(sc.loc[sc_7].profit.sum())
sc_profit.append(sc.loc[sc_8].profit.sum())
sc_profit.append(sc.loc[sc_9].profit.sum())
sc_profit.append(sc.loc[sc_10].profit.sum())
sc_profit.append(sc.loc[sc_11].profit.sum())
sc_profit.append(sc.loc[sc_12].profit.sum())
sc_profit.append(sc.loc[sc_1].profit.sum())
sc_profit.append(sc.loc[sc_2].profit.sum())
sc_profit.append(sc.loc[sc_3].profit.sum())
sc_profit.append(sc.loc[sc_4].profit.sum())

ch= monthly.query("store == '천호점'")

ch_7= (ch['date_time'] >= '2000-07-01') & (ch['date_time'] <= '2000-07-31')
ch_8= (ch['date_time'] >= '2000-08-01') & (ch['date_time'] <= '2000-08-31')
ch_9= (ch['date_time'] >= '2000-09-01') & (ch['date_time'] <= '2000-09-31')
ch_10= (ch['date_time'] >= '2000-10-01') & (ch['date_time'] <= '2000-10-31')
ch_11= (ch['date_time'] >= '2000-11-01') & (ch['date_time'] <= '2000-11-31')
ch_12= (ch['date_time'] >= '2000-12-01') & (ch['date_time'] <= '2000-12-31')
ch_1= (ch['date_time'] >= '2001-01-01') & (ch['date_time'] <= '2001-01-31')
ch_2= (ch['date_time'] >= '2001-02-01') & (ch['date_time'] <= '2001-02-31')
ch_3= (ch['date_time'] >= '2001-03-01') & (ch['date_time'] <= '2001-03-31')
ch_4= (ch['date_time'] >= '2001-04-01') & (ch['date_time'] <= '2001-04-31')

ch_profit=[]
ch_profit.append(ch.loc[ch_7].profit.sum())
ch_profit.append(ch.loc[ch_8].profit.sum())
ch_profit.append(ch.loc[ch_9].profit.sum())
ch_profit.append(ch.loc[ch_10].profit.sum())
ch_profit.append(ch.loc[ch_11].profit.sum())
ch_profit.append(ch.loc[ch_12].profit.sum())
ch_profit.append(ch.loc[ch_1].profit.sum())
ch_profit.append(ch.loc[ch_2].profit.sum())
ch_profit.append(ch.loc[ch_3].profit.sum())
ch_profit.append(ch.loc[ch_4].profit.sum())

# %%
ch_profit
# Out:
# [1362132067,
#  957293379,
#  1388279047,
#  1645332511,
#  1428722169,
#  1562627378,
#  1431886873,
#  1077721353,
#  1244606475,
#  1743383536]

# %%
trade_profit
# Out:
# [2370545026,
#  1717835322,
#  2336774618,
#  2499488938,
#  2396948943,
#  2570937309,
#  2381602296,
#  1869824113,
#  2282990814,
#  2885170521]

# %%
year_month=['2000-07','2000-08','2000-09','2000-10','2000-11','2000-12','2001-01','2001-02','2001-03','2001-04']
plt.figure(figsize=(12,8))
plt.plot(year_month,trade_profit,label='무역점',linestyle='-', color='r')
plt.plot(year_month, origin_profit,label='본점', linestyle='-', color='g')
plt.plot(year_month, ch_profit, label='신촌점' ,linestyle='-', color='b')
plt.plot(year_month, sc_profit,  label='천호점',linestyle='-', color='y')

plt.title('점포별 월 매출총이익', fontsize=15) 
plt.xticks(rotation=45,fontsize=18)
plt.ylabel('매출액(단위:10억)', fontsize=16)
plt.xlabel('월', fontsize=16)
plt.yticks(fontsize=18)
plt.legend(fontsize=16)
plt.show()

# %%
july
# Out:
#                 date_time store   profit
# 24       2000-07-08 11:50   무역점   126000
# 78       2000-07-27 14:03   무역점    57000
# 79       2000-07-27 14:43   무역점   357200
# 80       2000-07-27 14:50   무역점    49000
# 81       2000-07-30 14:40   무역점   560000
# ...                   ...   ...      ...
# 1036541  2000-07-23 10:30   무역점   455000
# 1036542  2000-07-23 11:03   무역점    42750
# 1036543  2000-07-25 17:10   무역점  1506000
# 1036544  2000-07-27 14:40   무역점    64000
# 1036641  2000-07-29 14:00   무역점    45600
#
# [26806 rows x 3 columns]

# %%
trade = monthly.query("store == '무역점'")
trade_data = trade.sort_values('date_time').reset_index().drop(columns='index')
tradeJuly= (trade['date_time'] >= '2000-07-01') & (trade['date_time'] <= '2000-07-31')
july=trade.loc[tradeJuly]
# 무역점 7월 profit 합계
july.profit.sum()
# Out:
# 2370545026

# %%
with open('merge_data.csv', encoding='utf-8') as f, open('merge_data.csv', 'w', encoding='cp949') as fw:
    data = f.read()
    fw.write(data)

# %%
fw
# Out:
# <_io.TextIOWrapper name='merge_data.csv' mode='w' encoding='cp949'>
